# %%
import pandas as pd
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#         Unnamed: 0      0      1
# 0                0  5.651  2.624
# 1                1  5.612  2.562
# 2                2  5.544  2.457
# 3                3  5.529  2.433
# 4                4  5.517  2.414
# ...            ...    ...    ...
# 103433      103433  6.207  3.493
# 103434      103434  6.060  3.264
# 103435      103435  5.926  3.054
# 103436      103436  5.816  2.882
# 103437      103437  5.712  2.719
#
# [103438 rows x 3 columns]

# %%
#mu = 0.1

df_lms = pd.read_csv('lms_error_mu_0.1.csv')
df_rls = pd.read_csv('rls_error_mu_0.1.csv')

# plt.figure(figsize = [9,7])
plt.figure()

plt.plot(df_lms.iloc[:,0], df_lms.iloc[:,1], c = 'blue')
plt.plot(df_rls.iloc[:,0], df_rls.iloc[:,1], c = 'red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#mu = 0.01

df_lms = pd.read_csv('lms_error_mu_0.01.csv')
df_rls = pd.read_csv('rls_error_mu_0.01.csv')

# plt.figure(figsize = [9,7])
plt.figure()

plt.plot(df_lms.iloc[:,0], df_lms.iloc[:,1], c = 'blue')
plt.plot(df_rls.iloc[:,0], df_rls.iloc[:,1], c = 'red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#mu = 0.001

df_lms = pd.read_csv('lms_error_mu_0.001.csv')
df_rls = pd.read_csv('rls_error_mu_0.001.csv')

# plt.figure(figsize = [9,7])
plt.figure()

plt.plot(df_lms.iloc[:,0], df_lms.iloc[:,1], c = 'blue')
plt.plot(df_rls.iloc[:,0], df_rls.iloc[:,1], c = 'red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#mu = 0.0001

df_lms = pd.read_csv('lms_error_mu_0.0001.csv')
df_rls = pd.read_csv('rls_error_mu_0.0001.csv')

# plt.figure(figsize = [9,7])
plt.figure()

plt.plot(df_lms.iloc[:,0], df_lms.iloc[:,1], c = 'blue')
plt.plot(df_rls.iloc[:,0], df_rls.iloc[:,1], c = 'red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(figsize = [10,10])
plt.subplot(2,2,1)

#mu = 0.1

df_lms = pd.read_csv('lms_error_mu_0.1.csv')
df_rls = pd.read_csv('rls_error_mu_0.1.csv')
plt.plot(df_lms.iloc[:,0], df_lms.iloc[:,1], c = 'blue')
plt.plot(df_rls.iloc[:,0], df_rls.iloc[:,1], c = 'red')


plt.subplot(2,2,2)

#mu = 0.1

df_lms = pd.read_csv('lms_error_mu_0.01.csv')
df_rls = pd.read_csv('rls_error_mu_0.01.csv')
plt.plot(df_lms.iloc[:,0], df_lms.iloc[:,1], c = 'blue')
plt.plot(df_rls.iloc[:,0], df_rls.iloc[:,1], c = 'red')

plt.subplot(2,2,3)

#mu = 0.1

df_lms = pd.read_csv('lms_error_mu_0.001.csv')
df_rls = pd.read_csv('rls_error_mu_0.001.csv')
plt.plot(df_lms.iloc[:,0], df_lms.iloc[:,1], c = 'blue')
plt.plot(df_rls.iloc[:,0], df_rls.iloc[:,1], c = 'red')

plt.subplot(2,2,4)

#mu = 0.1

df_lms = pd.read_csv('lms_error_mu_0.0001.csv')
df_rls = pd.read_csv('rls_error_mu_0.0001.csv')
plt.plot(df_lms.iloc[:,0], df_lms.iloc[:,1], c = 'blue')
plt.plot(df_rls.iloc[:,0], df_rls.iloc[:,1], c = 'red')
# Out:
# <img src="data:image/png;base64,..." width="1000">
